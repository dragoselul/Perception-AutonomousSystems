# %%
import zipfile
import os

zip_path = "C:\\Users\\mjgoj\\Desktop\\Perception-AutonomousSystems\\Project\\archive.zip"
target_folder = "data_object_image_2/"      # folder inside the zip
extract_to = "C:\\Users\\mjgoj\\Desktop\\Perception-AutonomousSystems\\Project\\data\\data_object_image_2\\"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    for member in zip_ref.namelist():
        if member.startswith(target_folder):
            zip_ref.extract(member, extract_to)
