# %% [markdown]
# # Exercise 1: Linear regression
# Initially we will work on 2D points and then expand it out to 3D.
#
# We'll do the necessary imports for the notebook and then generate some data.
#
# The data generation is as follows:
# $$
# x \sim \mathcal{N}(\mu_x, \sigma_x^2)
# $$
# with $\mu_x=1.5$ being the mean and $\sigma_x = 2.5$ being the standard deviation.
#
# We also add a normally distributed error term with zero mean $\mu_\epsilon=0$ and standard deviation
# $\sigma_\epsilon=0.5$.

# %%
import numpy as np
import open3d as o3d
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D

# Generate 'random' data
np.random.seed(0)
x = np.random.normal(1.5, 2.5, 100)   # Array of 100 values with mean = 1.5, stddev = 2.5
res = np.random.normal(0, 0.5, 100)       # Generate 100 residual terms (mean=0, std=0.5)
y = 2 + 0.3 * x + res                  # Actual values of Y
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# We can use the linear regression algorithm from the `sklearn` package.
# Here, we setup the model to fit `x` to `y`.

# %%
x_r = x.reshape(-1,1) #fit needs x in this shape
# Initialise and fit model
lm = LinearRegression()
model = lm.fit(x_r, y)

# %% [markdown]
# We can now predict new outcomes given new data.

# %%
# Draw a new datapoint
tst_x = 2.5 * np.random.randn(1).reshape(-1,1) + 1.5   
print(tst_x)
resulting_y = model.predict(tst_x)
print(resulting_y)
# Out:
# [[0.57704541]]
# [2.18951787]

# %% [markdown]
# Drawing 200 new samples and plotting them as a line shows us that we have gotten a decent fit.

# %%
new_x = 2.5 * np.random.randn(200).reshape(-1,1) + 1.5   
predicted = model.predict(new_x)
plt.figure(figsize=(8, 6))
plt.plot(new_x, predicted)     # regression line
plt.plot(x, y, 'ro')   # scatter plot showing actual data
plt.title('Actual vs Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Exercises
# ### A
# Using [Ordinary Least Squares (OLS)](https://en.wikipedia.org/wiki/Ordinary_least_squares), attempt to get a regression line that is equal to the one `sklearn` provides.
#
# Assuming that the data is modeled by the following, having $N$ data points available:
# $$
# \underbrace{\hat{\mathbf{y}}}_{N \times 1} = \underbrace{\mathbf{X}}_{N\times (K+1)} \underbrace{\beta^\text{*}}_{(K+1) \times 1} + \underbrace{\varepsilon}_{N \times 1}
# $$
# Ordinary Least squares optimizes the parameters $\beta$ such that the resdiual error (measured by the Sum of Squared Errors (SSE) objective/loss function $L$) is minimal (regression). That is:
# $$
# L(\mathbf{X}_i, y_i;\mathbf{\beta}) = \sum_{i=1}^N (y_i - \hat{y_i})^2 \\
# \beta^\text{*} = \argmin_\beta L(\mathbf{X}, \mathbf{y};\beta)
# $$
# where $y_i$ is the true value and $\hat{y_i}$ is the predicted value given a point $\mathbf{X}_i \in \mathbb{R}$.
# We won't go into detail here how to solve this optimization problem but instead give you the solution directly:
# $$
# \beta^\text{*} = (\mathbf{X}^\top \mathbf{X})^{-1}\mathbf{X}^\top \mathbf{y}
# $$
# Using this, you need to organize your data in matrices of shapes $(N, K+1)$ for $\mathbf{X}$ with $N$ being the number of data points and $K$ being the dimension of $\mathbf{X_i}$, i.e. $\mathbf{X}_i \in \mathbb{R}^K$. The $+1$ is for the intercept, so $\beta_0$ will be our intercept term. For $\mathbf{y}$, you need to make sure it is of shape $(N, 1)$. So, the first row of $\mathbf{X}$ would look like this if $\mathbf{X}_i \in \mathbb{R}$:
# $$
# \mathbf{X_0} = \begin{bmatrix}1 & x_{1,0}\end{bmatrix}
# $$
# <details open>
# <summary>If the above formulation is too complicated, here's another formulation</summary>
# <br>
# Assuming
# Yₑ = α + β X
#
# ![ols.gif](ols.gif "ols")
#
# - β = Cov(X, Y) / Var(X).
# - α = mean(Y)-β*mean(X)
#
# </br>
# </details>
#
# ### B
# Extend what we have shown above to 3D predict a plane using Linear regression given a point cloud.
#
# Planes can be plotted with
# ```{Python}
# x = np.linspace(start, end, n)
# y = np.linspace(start, end, n)
# xx, yy = np.meshgrid(x_t, y_t)
#
# ax.plot_surface(xx, yy, predicted_zz, alpha=0.2)
# ```

# %%
# Creating a pointcloud.
pc = o3d.io.read_point_cloud("TestData/spread_points.ply")
xyz = np.asarray(pc.points)

fig = plt.figure(figsize=(6,4))
ax = plt.axes(projection='3d')
ax.scatter3D(xyz[:,0], xyz[:,1], xyz[:,2], color = 'red')
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.set_zlabel('z', fontsize=12)
plt.show()

# %%
## We want to predict Z
xy = xyz[:,:2] # our inputs
z = xyz[:,2].reshape(-1,1) # our targets

# %% [markdown]
# ## Exercise A: Implement OLS from Scratch

# %%
print("=== Exercise A: OLS Implementation ===\n")

# Method 1: Using the matrix formula β* = (X^T X)^-1 X^T y
# Add column of ones for intercept term
X = np.column_stack([np.ones(len(x)), x])  # Shape: (N, 2) - first column is 1s, second is x values
y_col = y.reshape(-1, 1)  # Shape: (N, 1)

# Calculate β* = (X^T X)^-1 X^T y
beta = np.linalg.inv(X.T @ X) @ X.T @ y_col

print("Method 1: Matrix Formula")
print(f"β₀ (intercept): {beta[0, 0]:.6f}")
print(f"β₁ (slope): {beta[1, 0]:.6f}")

# Method 2: Simpler covariance formula
# β = Cov(X, Y) / Var(X)
# α = mean(Y) - β * mean(X)
slope = np.cov(x, y)[0, 1] / np.var(x)
intercept = np.mean(y) - slope * np.mean(x)

print(f"\nMethod 2: Covariance Formula")
print(f"α (intercept): {intercept:.6f}")
print(f"β (slope): {slope:.6f}")

# Compare with sklearn
print(f"\nsklearn Results:")
print(f"Intercept: {model.intercept_:.6f}")
print(f"Slope: {model.coef_[0]:.6f}")

# Visualize comparison
new_x = np.linspace(x.min(), x.max(), 100)
y_manual = beta[0, 0] + beta[1, 0] * new_x
y_sklearn = model.predict(new_x.reshape(-1, 1))

plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.5, label='Data')
plt.plot(new_x, y_manual, 'r-', linewidth=2, label='Manual OLS')
plt.plot(new_x, y_sklearn, 'g--', linewidth=2, label='sklearn')
plt.xlabel('x')
plt.ylabel('y')
plt.title('OLS: Manual vs sklearn')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("\n✓ Both methods match sklearn!")
# Out:
# === Exercise A: OLS Implementation ===
#
# Method 1: Matrix Formula
# β₀ (intercept): 2.003167
# β₁ (slope): 0.322940
#
# Method 2: Covariance Formula
# α (intercept): 1.997786
# β (slope): 0.326202
#
# sklearn Results:
# Intercept: 2.003167
# Slope: 0.322940
# ✓ Both methods match sklearn!

# %% [markdown]
# ## Exercise B: 3D Plane Fitting

# %%
print("=== Exercise B: 3D Plane Fitting ===\n")

# Fit plane: z = β₀ + β₁*x + β₂*y
# Add column of ones for intercept
X_3d = np.column_stack([np.ones(len(xy)), xy])  # Shape: (N, 3)

# Calculate β* = (X^T X)^-1 X^T z
beta_3d = np.linalg.inv(X_3d.T @ X_3d) @ X_3d.T @ z

print(f"Plane equation: z = {beta_3d[0, 0]:.4f} + {beta_3d[1, 0]:.4f}*x + {beta_3d[2, 0]:.4f}*y")

# Also use sklearn for comparison
model_3d = LinearRegression()
model_3d.fit(xy, z)
print(f"\nsklearn plane: z = {model_3d.intercept_[0]:.4f} + {model_3d.coef_[0][0]:.4f}*x + {model_3d.coef_[0][1]:.4f}*y")

# Create mesh grid for plotting the plane
x_range = np.linspace(xyz[:, 0].min(), xyz[:, 0].max(), 20)
y_range = np.linspace(xyz[:, 1].min(), xyz[:, 1].max(), 20)
xx, yy = np.meshgrid(x_range, y_range)

# Predict z values for the grid
zz = beta_3d[0, 0] + beta_3d[1, 0] * xx + beta_3d[2, 0] * yy

# Plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot original points
ax.scatter3D(xyz[:, 0], xyz[:, 1], xyz[:, 2], c='red', marker='o', s=20, label='Data Points')

# Plot fitted plane
ax.plot_surface(xx, yy, zz, alpha=0.3, color='blue', label='Fitted Plane')

ax.set_xlabel('X', fontsize=12)
ax.set_ylabel('Y', fontsize=12)
ax.set_zlabel('Z', fontsize=12)
ax.set_title('3D Plane Fitting with OLS', fontsize=14)
plt.legend()
plt.show()

# Calculate R² score (goodness of fit)
z_pred = X_3d @ beta_3d
ss_res = np.sum((z - z_pred) ** 2)
ss_tot = np.sum((z - np.mean(z)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"\nR² score: {r2[0]:.6f}")
print(f"sklearn R² score: {model_3d.score(xy, z):.6f}")
print("\n✓ Plane fitted successfully!")
# Out:
# === Exercise B: 3D Plane Fitting ===
#
# Plane equation: z = 10.8136 + 0.0324*x + 1.5270*y
#
# sklearn plane: z = 10.8136 + 0.0324*x + 1.5270*y
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 48
#      45 ss_tot = np.sum((z - np.mean(z)) ** 2)
#      46 r2 = 1 - (ss_res / ss_tot)
# ---> 48 print(f"\nR² score: {r2[0]:.6f}")
#      49 print(f"sklearn R² score: {model_3d.score(xy, z):.6f}")
#      50 print("\n✓ Plane fitted successfully!")
#
# IndexError: invalid index to scalar variable.
